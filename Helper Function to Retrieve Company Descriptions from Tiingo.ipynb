# %%
import urllib3
from urllib3 import *
import pandas as pd
import time
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm
from scipy.stats import spearmanr
import sys
import datetime
import os
import time
import matplotlib.cbook as cbook
import seaborn as sns
import math as mth
from math import exp
import pylab
import pickle
from bs4 import BeautifulSoup
import re
import nltk
import string
import pprint
import sklearn


import bokeh
from bokeh.plotting import *
from collections import OrderedDict
from bokeh.io import output_notebook
from bokeh.models import Toggle, BoxAnnotation, CustomJS, HoverTool
output_notebook()

import plotly
import plotly.graph_objs as go
from plotly.graph_objs import *
import plotly.plotly as py
import plotly.tools as tls
import plotly.offline as offline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import pytz

offline.init_notebook_mode(connected=False)
init_notebook_mode(connected=False)

import cufflinks as cf
import colorlover as cl
#Plotly API Information:(username='asl4af', api_key='7ut55tktdt')
plotly.tools.set_credentials_file(username='Zanderl',api_key='YOUR KEY HERE')

#Make all charts public and set a global theme
cf.set_config_file(world_readable=True,theme='white',offline=True)

tls.embed('https://plot.ly/~cufflinks/8')

sns.set_style("white")
#sns.set_style("darkgrid")
#sns.set(style="darkgrid", palette="Set2")
#sns.set(style="darkgrid", context="paper", font="monospace")

# %matplotlib inline
#mpl.style.use('ggplot')

from IPython.display import display

from IPython.display import HTML

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b8dc5c18-3404-4ff4-81a4-315e26acf3bd">Loading BokehJS ...</span>
#     </div>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~cufflinks/8.embed" height="525" width="100%"></iframe>

# %%
from tiingo import TiingoClient

config = {}

config['api_key'] = "06116d5e0fde515461a370219042afbfa023b85c"

client = TiingoClient(config)

# %%
avail_data = pd.read_csv("C:/Users/Zander Luke/TiingoAvailableData.csv")

# %%
avail_data.head()
# Out:
#    Unnamed: 0  ticker exchange assetType priceCurrency   startDate     endDate
# 0           0  000001      SHE     Stock           CNY  2017-01-03  2018-01-31
# 1           1  000002      SHE     Stock           CNY  2007-01-04  2018-01-31
# 2           2  000004      SHE     Stock           CNY  2007-01-04  2018-01-31
# 3           3  000005      SHE     Stock           CNY  2017-01-03  2018-01-31
# 4           4  000006      SHE     Stock           CNY  2007-01-04  2017-09-08

# %%
symbol_list = list(avail_data[3500:4000]['ticker'])

# %%
len(symbol_list)
# Out:
# 500

# %%
#sl_test = list(symbol_list[:25])

# %%
# %%time

#symbol_descripts = pd.DataFrame(columns=['description','name','startDate','endDate','exchangeCode','ticker'])



sym_data = []

for symbol in symbol_list:
    m_data = client.get_ticker_metadata(str(symbol))
    sym_data.append(m_data)
    sym_df = pd.DataFrame(sym_data)
    sym_df.index = sym_df['ticker']
# Out:
# Wall time: 1min 41s

# %%
sym_df.head(10)
# Out:
#                                               description     endDate  \
# ticker
# 601011  Qitaihe Baotailong Coal & Coal Chemicals Publi...  2018-02-02
# 601012  Xi'an LONGi Silicon Materials Corp. is a China...  2018-02-02
# 601015                                                     2018-02-02
# 601016                                                     2018-02-02
# 601018  Ningbo Port Company Limited is principally eng...  2018-02-02
# 601019                                                           None
# 601020                                                     2018-02-02
# 601021                                                     2018-02-02
# 601028  Jiangsu Yulong Steel Pipe Co., Ltd. is a China...  2018-02-02
# 601038  First Tractor Company Limited is principally e...  2018-02-02
#
#        exchangeCode                                      name   startDate  \
# ticker
# 601011          SHG            Qitaihe Baotailong Coal & Coal  2011-03-09
# ...

# %%
sym_df.describe(percentiles=[0.25,0.50,0.75],include='all')
# Out:
#        description     endDate exchangeCode name   startDate  ticker
# count          500         404          500  410         404     500
# unique         133          16            1  133         325     500
# top                 2018-02-02          SHG       2017-01-03  603096
# freq           368         386          500  278          15       1

# %%
sym_df['description'].head()
# Out:
# ticker
# 601011    Qitaihe Baotailong Coal & Coal Chemicals Publi...
# 601012    Xi'an LONGi Silicon Materials Corp. is a China...
# 601015
# 601016
# 601018    Ningbo Port Company Limited is principally eng...
# Name: description, dtype: object

# %%
sym_df.to_excel('TiingoQuoteData_3000-3500.xlsx')
