# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Upgrades/Downgrades

# %%
upgrades_df = pd.read_html('https://www.marketwatch.com/tools/stockresearch/updown/?type=5')

# %%
upgrades_df[0]
# Out:
#           Date Symbol                                         Company  \
# 0    2/16/2018    AAN                                         Aaron's
# 1    2/16/2018   AAPL                                           Apple
# 2    2/16/2018   AERI                           Aerie Pharmaceuticals
# 3    2/16/2018   AIRG                                         Airgain
# 4    2/16/2018    ALL                                        Allstate
# 5    2/16/2018   ALRM                              Alarm.com Holdings
# 6    2/16/2018   ALSN                            Allison Transmission
# 7    2/16/2018   ALSN                            Allison Transmission
# 8    2/16/2018   ALSN                            Allison Transmission
# 9    2/16/2018   AMBR                                      Amber Road
# 10   2/16/2018   ANET                                 Arista Networks
# 11   2/16/2018   APRI                             Apricus Biosciences
# ...

# %% [markdown]
# # Gainers

# %%
gainers_df = pd.read_html('https://www.finviz.com/screener.ashx?v=111&s=ta_topgainers&o=-change')

# %%
gainers_df[14]
# Out:
#      0       1                                     2                 3   \
# 0   No.  Ticker                               Company            Sector
# 1     1    XTNT          Xtant Medical Holdings, Inc.        Healthcare
# 2     2    SNCR        Synchronoss Technologies, Inc.        Technology
# 3     3    MULE                        MuleSoft, Inc.        Technology
# 4     4     GEN              Genesis Healthcare, Inc.        Healthcare
# 5     5    NAVG            The Navigators Group, Inc.         Financial
# 6     6    CALA           Calithera Biosciences, Inc.        Healthcare
# 7     7     PAR            PAR Technology Corporation        Technology
# 8     8    SSTI                     ShotSpotter, Inc.        Technology
# 9     9    CATB       Catabasis Pharmaceuticals, Inc.        Healthcare
# 10   10       X       United States Steel Corporation   Basic Materials
# 11   11     AKS          AK Steel Holding Corporation   Basic Materials
# ...

# %% [markdown]
# # Losers

# %%
losers_df = pd.read_html('https://www.finviz.com/screener.ashx?v=111&s=ta_toplosers')

# %%
losers_df[14]
# Out:
#      0       1                                 2                3   \
# 0   No.  Ticker                           Company           Sector
# 1     1    APRI         Apricus Biosciences, Inc.       Healthcare
# 2     2    RIOT             Riot Blockchain, Inc.       Healthcare
# 3     3    NNDM               Nano Dimension Ltd.       Technology
# 4     4    MBRX           Moleculin Biotech, Inc.       Healthcare
# 5     5     CLD            Cloud Peak Energy Inc.  Basic Materials
# 6     6    ANET             Arista Networks, Inc.       Technology
# 7     7    LFIN                     Longfin Corp.       Technology
# 8     8     CGG                            CGG SA  Basic Materials
# 9     9      PI                      Impinj, Inc.       Technology
# 10   10    PCRX      Pacira Pharmaceuticals, Inc.       Healthcare
# 11   11    COHU                        Cohu, Inc.       Technology
# 12   12    PXLW                  Pixelworks, Inc.       Technology
# ...

# %% [markdown]
# # New Highs

# %%
new_highs_df = pd.read_html('https://www.finviz.com/screener.ashx?v=111&s=ta_newhigh')

# %%
new_highs_df[14]
# Out:
#      0       1                                    2                 3   \
# 0   No.  Ticker                              Company            Sector
# 1     1    ARMO               ARMO BioSciences, Inc.        Healthcare
# 2     2    GLOB                         Globant S.A.        Technology
# 3     3    ALKS                         Alkermes plc        Healthcare
# 4     4       X      United States Steel Corporation   Basic Materials
# 5     5    NVAX                        Novavax, Inc.        Healthcare
# 6     6    CARB                      Carbonite, Inc.        Technology
# 7     7    IMGN                      ImmunoGen, Inc.        Healthcare
# 8     8    MULE                       MuleSoft, Inc.        Technology
# 9     9    MSBF                  MSB Financial Corp.         Financial
# 10   10     ESP       Espey Mfg. & Electronics Corp.        Technology
# 11   11     GGB                          Gerdau S.A.   Basic Materials
# ...

# %% [markdown]
# # New Lows

# %%
new_lows_df = pd.read_html('https://www.finviz.com/screener.ashx?v=111&s=ta_newlow')

# %%
new_lows_df[14]
# Out:
#      0       1                                        2                3   \
# 0   No.  Ticker                                  Company           Sector
# 1     1    NNDM                      Nano Dimension Ltd.       Technology
# 2     2    JRJR                             JRjr33, Inc.         Services
# 3     3    AMDA                      Amedica Corporation       Healthcare
# 4     4    AVGR                            Avinger, Inc.       Healthcare
# 5     5    DTRM                          Determine, Inc.       Technology
# 6     6      PI                             Impinj, Inc.       Technology
# 7     7    PDFS                      PDF Solutions, Inc.       Technology
# 8     8    REXX                   Rex Energy Corporation  Basic Materials
# 9     9    IPCI  IntelliPharmaCeutics International Inc.       Healthcare
# 10   10     UPL                    Ultra Petroleum Corp.  Basic Materials
# 11   11      SN               Sanchez Energy Corporation  Basic Materials
# ...
